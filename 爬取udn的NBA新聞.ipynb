# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

def get_soup(url):
    try:
        resp=requests.get(url)
        resp.encoding='utf-8'
        if resp.status_code==200:
            soup=BeautifulSoup(resp.text,'lxml')
            return soup
        else:
            print('網頁取得失敗',resp.status_code)
    except Exception as e:
        print('網址錯誤',e)

# %%
url=('https://tw-nba.udn.com/nba/cate/6754')

# %%
soup=get_soup(url)

# %%
cfs=soup.find(id='news_list_body').find_all('dt')

# %%
cf=cfs[0]

# %%
datas=[]
for cf in cfs:
    try:
        title=cf.find('h3').text
        title=title.lstrip('NBA/').replace('/','')
        source='聯合新聞網'
        content=cf.find('p').text
        img_url=cf.find('img').get('data-src')
        news_url=cf.find('a').get('href')
        datas.append([title,source,content,news_url,img_url])
    except Exception as e:
        print(e)

# %%
df= pd.DataFrame(datas,columns=['標題','來源','摘要','新聞連結','圖片連結'])

# %%
df
# Out:
#                            標題     來源  \
# 0   ／超越籃球之神！籃網小將生涯前10場先發得分創紀錄  聯合新聞網
# 1    ／從訓練營到最高殿堂 霍姆葛倫圓夢與柯瑞互換球衣  聯合新聞網
# 2    ／格林未造成球不自然彈跳 官方解釋不構成妨礙中籃  聯合新聞網
# 3    ／決勝時刻進攻大當機 灰熊無力守成苦吞開季6連敗  聯合新聞網
# 4    ／約柯奇準大三元力退唐西奇 厄文回歸獨行俠嚐首敗  聯合新聞網
# 5     ／吉迪先碰網拯救了格林 柯瑞致勝上籃柯爾喊僥倖  聯合新聞網
# 6    ／赫洛準大三元熱火止4連敗 巴特勒：防守還不夠好  聯合新聞網
# 7   ／格林差點毀了柯瑞致勝球 勇士連兩戰準絕殺奪5連勝  聯合新聞網
# 8  ／里拉德關鍵球助公鹿險勝 布朗森生涯次高45分做白工  聯合新聞網
# 9   ／公鹿防守效率跌谷底 安戴托昆波：訝異磨合要這麼久  聯合新聞網
#
#                                                   摘要  \
# 0  籃網隊的湯瑪斯（Cam Thomas）持續他的飆分之旅。今天對公牛一戰是他生涯第10次擔任先...
# 1  雷霆新星霍姆葛倫（Chet Holmgren）等了一年終於能夠盡情釋放天賦，在對勇士一戰中，...
# 2  柯瑞（Stephen Curry）在客場對雷霆的比賽中演出致勝上籃，不過後續格林（Draym...
# 3  開季一勝難求的灰熊，在作客波特蘭的第四節剩下3分多鐘時，還掌握10分領先優勢，眼看就要勝場開...
# 4  約柯奇（Nikola Jokic）和唐西奇（Luka Doncic）兩大歐陸球星今天在季中錦...
# 5  繼前一場湯普森（Klay Thompson）在剩下0.2秒上演致勝跳投後，柯瑞（Stephe...
# 6  在熱火不敵籃網苦吞4連敗的比賽結束後，赫洛（Tyler Herro）直言雖然現在才剛開季，但...
# 7  勇士今天作客雷霆主場進行季中錦標賽，兩隊在整場比賽一路拉鋸下，在正規賽倒數0.2秒勇士主控柯...
# 8  「防守端的破洞只能靠進攻火力來填補」，對開季以來團隊防守效率跌到聯盟倒數的公鹿來說，這或許是...
# 9  季前大動作換來超級射手里拉德（Damian Lillard），他與「希臘怪物」安戴托昆波（G...
#
#                                             新聞連結  \
# 0  https://tw-nba.udn.com/nba/story/7002/7551691
# 1  https://tw-nba.udn.com/nba/story/7002/7551630
# 2  https://tw-nba.udn.com/nba/story/7002/7551503
# 3  https://tw-nba.udn.com/nba/story/7002/7551429
# 4  https://tw-nba.udn.com/nba/story/7002/7551387
# 5  https://tw-nba.udn.com/nba/story/7002/7551326
# 6  https://tw-nba.udn.com/nba/story/7002/7551238
# 7  https://tw-nba.udn.com/nba/story/7002/7551145
# 8  https://tw-nba.udn.com/nba/story/7002/7551076
# 9  https://tw-nba.udn.com/nba/story/7002/7551033
#
#                                                 圖片連結
# 0  https://pgw.udn.com.tw/gw/photo.php?u=https://...
# 1  https://pgw.udn.com.tw/gw/photo.php?u=https://...
# 2  https://pgw.udn.com.tw/gw/photo.php?u=https://...
# 3  https://pgw.udn.com.tw/gw/photo.php?u=https://...
# 4  https://pgw.udn.com.tw/gw/photo.php?u=https://...
# 5  https://pgw.udn.com.tw/gw/photo.php?u=https://...
# 6  https://pgw.udn.com.tw/gw/photo.php?u=https://...
# 7  https://pgw.udn.com.tw/gw/photo.php?u=https://...
# 8  https://pgw.udn.com.tw/gw/photo.php?u=https://...
# 9  https://pgw.udn.com.tw/gw/photo.php?u=https://...
